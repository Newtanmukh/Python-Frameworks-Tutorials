# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('datasets/lego_sets.csv')
theme = pd.read_csv('datasets/parent_themes.csv')

# %%
df.head()
# Out:
#   set_num                        name  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space

# %%
theme.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %%
merged_df = df.merge(theme, left_on  = 'parent_theme', right_on = 'name')

# %%
merged_df.head()
# Out:
#   set_num                      name_x  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme   id    name_y  is_licensed
# 0     Legoland  411  Legoland        False
# 1         Town   50      Town        False
# 2       Castle  186    Castle        False
# 3        Space  126     Space        False
# 4        Space  126     Space        False

# %%
merged_df = merged_df.drop(columns = 'name_y')

# %%
licensed = merged_df[merged_df['is_licensed']==True]

# %%
licensed = licensed.dropna(subset = ['set_num'])

# %%
licensed.head()
# Out:
#     set_num                         name_x  year  num_parts  \
# 44  10018-1                     Darth Maul  2001     1868.0
# 45  10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 54  10026-1        Naboo Starfighter - UCS  2002        NaN
# 57  10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 95  10075-1         Spider-Man Action Pack  2002       25.0
#
#                  theme_name  parent_theme   id  is_licensed
# 44                Star Wars     Star Wars  158         True
# 45  Star Wars Episode 4/5/6     Star Wars  158         True
# 54      Star Wars Episode 1     Star Wars  158         True
# 57  Star Wars Episode 4/5/6     Star Wars  158         True
# 95               Spider-Man  Super Heroes  482         True

# %%
star_wars = licensed[licensed['parent_theme']=='Star Wars']

# %%
star_wars.head(5)
# Out:
#      set_num                         name_x  year  num_parts  \
# 44   10018-1                     Darth Maul  2001     1868.0
# 45   10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 54   10026-1        Naboo Starfighter - UCS  2002        NaN
# 57   10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 116  10123-1                     Cloud City  2003      707.0
#
#                   theme_name parent_theme   id  is_licensed
# 44                 Star Wars    Star Wars  158         True
# 45   Star Wars Episode 4/5/6    Star Wars  158         True
# 54       Star Wars Episode 1    Star Wars  158         True
# 57   Star Wars Episode 4/5/6    Star Wars  158         True
# 116  Star Wars Episode 4/5/6    Star Wars  158         True

# %%
star_wars.shape[0]
# Out:
# 609

# %%
the_force = star_wars.shape[0]/licensed.shape[0]

# %%
print(the_force)
the_force = int(the_force)
print(the_force)
# Out:
# 0.5165394402035624
# 0

# %%
sort = licensed.sort_values('year')
sort['count'] = 1

# %%
sort.groupby(['year', 'parent_theme']).head()
# Out:
#       set_num                          name_x  year  num_parts  \
# 7837   7141-1                   Naboo Fighter  1999      179.0
# 7845   7150-1            TIE Fighter & Y-wing  1999        NaN
# 7847   7151-1                Sith Infiltrator  1999      244.0
# 7815   7131-1               Anakin's Podracer  1999      136.0
# 7856   7161-1                      Gungan Sub  1999      379.0
# ...       ...                             ...   ...        ...
# 3576  41143-1                 Berry's Kitchen  2017        NaN
# 3577  41144-1           Petite's Royal Stable  2017        NaN
# 3578  41145-1     Ariel and the Magical Spell  2017        NaN
# 3579  41146-1  Cinderella's Enchanted Evening  2017      347.0
# 7725  71042-1                     Silent Mary  2017     2286.0
#
#                     theme_name              parent_theme   id  is_licensed
# 7837       Star Wars Episode 1                 Star Wars  158         True
# 7845   Star Wars Episode 4/5/6                 Star Wars  158         True
# 7847       Star Wars Episode 1                 Star Wars  158         True
# 7815       Star Wars Episode 1                 Star Wars  158         True
# 7856       Star Wars Episode 1                 Star Wars  158         True
# ...                        ...                       ...  ...          ...
# 3576           Disney Princess           Disney Princess  579         True
# 3577           Disney Princess           Disney Princess  579         True
# 3578           Disney Princess           Disney Princess  579         True
# 3579           Disney Princess           Disney Princess  579         True
# 7725  Pirates of the Caribbean  Pirates of the Caribbean  263         True
#
# [345 rows x 8 columns]
