# %%
# %matplotlib inline 
#this will basically make the charts and every chart will be visible here only. otherwise other stuff wont run on browser
from matplotlib import pyplot as plt
plt.plot([2,1,4],[3,6,1])  #order matters
plt.title("Newtan's data") #title
plt.xlabel("age")
plt.ylabel("time")
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')
x=[1,5,4]
y=[23,45,89]
x2=[3,7,3]
y2=[5,8,9]

#if instead we use plt.plot(y), it will automatically index the x as 0,1,2 etc.

plt.plot(x,y,'*') # Use points instead of line.
plt.plot(x2,y2)
plt.show()
#----------------------------------------------------------------------------------------------------------------------


plt.plot(x,y,marker='>',ms=20) # marker will contain line, but the points will contain the dot to represent them. ms determines the size, is optional argument.
plt.show()

#----------------------------------------------------------------------------------------------------------------------

xpoints = np.array([0,2,4,6])
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o-.r',ms=14)  #for, marker|linestyle(edge basically)|colour
plt.show()

#----------------------------------------------------------------------------------------------------------------------

xpoints = np.array([0,2,4,7])
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'b', mfc = 'y') #mec depicts the colour of edge, mfc depicts the colour inside of the marker.
plt.show()

#----------------------------------------------------------------------------------------------------------------------

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = '-.',color='hotpink',linewidth='10', marker = 'o', ms = 20, mec = 'b', mfc = 'y') #ls here basically means the linestyle.
plt.show()

# %%
xpoints=([0,2,5,9])
ypoints = np.array([3, 8, 1, 10])

x1=([0,5,6,9])
y1=([9,11,7,5])

plt.plot(x1,y1, linestyle = '--',color='r',linewidth='7', marker = '<', ms = 18, mec = 'y', mfc = 'hotpink',label='fitst')
plt.plot(xpoints,ypoints, linestyle = '-.',color='hotpink',linewidth='7', marker = 'o', ms = 20, mec = 'b', mfc = 'y',label='second') #ls here basically means the linestyle.
plt.title("kuch bhi",loc='left')
plt.xlabel('aging',loc='right')
plt.ylabel('not aging')
plt.legend() # without this, the label wont work
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13668/1891666994.py in <module>
#       9 plt.title("kuch bhi",loc='left')
#      10 plt.xlabel('aging',loc='right')
# ---> 11 plt.ylabel('not aging',loc='left')
#      12 plt.legend() # without this, the label wont work
#      13 plt.show()
#
# D:\Users\Newtan\anaconda3\lib\site-packages\matplotlib\pyplot.py in ylabel(ylabel, fontdict, labelpad, loc, **kwargs)
#    3300 @_copy_docstring_and_deprecators(Axes.set_ylabel)
#    3301 def ylabel(ylabel, fontdict=None, labelpad=None, *, loc=None, **kwargs):
# -> 3302     return gca().set_ylabel(
#    3303         ylabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
#    3304         **kwargs)
#
# D:\Users\Newtan\anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_ylabel(self, ylabel, fontdict, labelpad, loc, **kwargs)
#    3675             loc = (loc if loc is not None
#    3676                    else mpl.rcParams['yaxis.labellocation'])
# -> 3677         _api.check_in_list(('bottom', 'center', 'top'), loc=loc)
#    3678         if loc == 'bottom':
#    3679             kwargs.update(y=0, horizontalalignment='left')
#
# D:\Users\Newtan\anaconda3\lib\site-packages\matplotlib\_api\__init__.py in check_in_list(_values, _print_supported_values, **kwargs)
#     124         if val not in values:
#     125             if _print_supported_values:
# --> 126                 raise ValueError(
#     127                     f"{val!r} is not a valid value for {key}; "
#     128                     f"supported values are {', '.join(map(repr, values))}")
#
# ValueError: 'left' is not a valid value for loc; supported values are 'bottom', 'center', 'top'
